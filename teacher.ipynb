# %%
import os
from sklearn.model_selection import train_test_split
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def convert_to_gray(img):
    gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    return gray_img

def convert_to_lab(img):
    lab_img = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    return lab_img

def extract_a_channel(lab_img):
    a_channel = lab_img[:, :, 1]

    return a_channel

def apply_clahe(a_channel):
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    equalized_a_channel = clahe.apply(a_channel)
    return equalized_a_channel

def dilate_image(img):
    kernel = np.ones((3, 3), np.uint8)
    dilated_img = cv2.dilate(img, kernel, iterations=1)

    return dilated_img

def apply_threshold(img):
    _, thresholded_img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    return thresholded_img

def preprocess_image(img):
    gray_img = convert_to_gray(img)
    lab_img = convert_to_lab(img)
    a_channel = extract_a_channel(lab_img)
    equalized_a_channel = apply_clahe(a_channel)
    dilated_img = dilate_image(equalized_a_channel)
    thresholded_img = apply_threshold(dilated_img)
    thresholded_img = np.expand_dims(thresholded_img, axis=-1)
    color_img = np.repeat(thresholded_img, 3, axis=-1)
    return color_img

# %%
def load_images_from_folder(folder, target_size=(256, 256), test_size=0.2):
    images = []
    labels = []

    for label, class_folder in enumerate(os.listdir(folder)):
        class_path = os.path.join(folder, class_folder)
        for filename in os.listdir(class_path):
            img_path = os.path.join(class_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, target_size)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                preprocessed_img = preprocess_image(img)
                images.append(preprocessed_img)
                labels.append(label)

    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=test_size, random_state=42)

    return X_train, X_test, y_train, y_test

# %%
folder_path = "C:\SUDHARSHAN\miniProject\Dataset2"
i=0
X_train, X_test, y_train, y_test = load_images_from_folder(folder_path)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1440, 256, 256, 3)
# X_test shape: (360, 256, 256, 3)
# y_train shape: (1440,)
# y_test shape: (360,)

# %%
import matplotlib.pyplot as plt

mappings={0:"Healthy",1:"Rice_blast",2:"BLB"}
def visualize_images(images, labels):
    fig, axes = plt.subplots(3, 5, figsize=(15, 9))
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i],cmap = "summer")
        ax.set_title(f"Label: {mappings[labels[i]]}")
        ax.axis('off')
    plt.show()

visualize_images(X_train[15:30], y_train[15:30])

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense
import tensorflow as tf

def create_model():
    
    def add_conv_block(model, num_filters):
        
        model.add(Conv2D(num_filters, 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(Conv2D(num_filters, 3, activation='relu', padding='valid'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.2))

        return model
    
    model = tf.keras.models.Sequential()
    model.add(Input(shape=(256, 256,3)))
    
    model = add_conv_block(model, 32)
    model = add_conv_block(model, 64)
    model = add_conv_block(model, 128)
    model = add_conv_block(model, 256)

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  batch_normalization (Batch  (None, 256, 256, 32)      128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 254, 254, 32)      9248
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 127, 127, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 127, 127, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 127, 127, 64)      256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 62, 62, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 62, 62, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 62, 62, 128)       512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 128)       147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 30, 30, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 30, 30, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 30, 30, 256)       1024
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 256)       590080
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 256)       0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 512)               25690624
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 26996899 (102.98 MB)
# Trainable params: 26995939 (102.98 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
# %%time

rice_bios_model = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100, batch_size=128
    )
# Out:
# Epoch 1/100
# 12/12 [==============================] - 239s 19s/step - loss: 23.7574 - accuracy: 0.3438 - val_loss: 1.4730 - val_accuracy: 0.2917
# Epoch 2/100
# 12/12 [==============================] - 227s 18s/step - loss: 2.3981 - accuracy: 0.3424 - val_loss: 1.5940 - val_accuracy: 0.3528
# Epoch 3/100
# 12/12 [==============================] - 222s 19s/step - loss: 1.1020 - accuracy: 0.3771 - val_loss: 1.1079 - val_accuracy: 0.3889
# Epoch 4/100
# 12/12 [==============================] - 225s 19s/step - loss: 1.0056 - accuracy: 0.4639 - val_loss: 1.9836 - val_accuracy: 0.2917
# Epoch 5/100
# 12/12 [==============================] - 224s 19s/step - loss: 0.9852 - accuracy: 0.4931 - val_loss: 1.0993 - val_accuracy: 0.3500
# Epoch 6/100
# 12/12 [==============================] - 222s 18s/step - loss: 0.9552 - accuracy: 0.5118 - val_loss: 1.1790 - val_accuracy: 0.3472
# Epoch 7/100
# 12/12 [==============================] - 223s 19s/step - loss: 0.8939 - accuracy: 0.5715 - val_loss: 1.1465 - val_accuracy: 0.3972
# Epoch 8/100
# 12/12 [==============================] - 215s 18s/step - loss: 0.8560 - accuracy: 0.5972 - val_loss: 0.9368 - val_accuracy: 0.5139
# Epoch 9/100
# 12/12 [==============================] - 215s 18s/step - loss: 0.8048 - accuracy: 0.6292 - val_loss: 0.8560 - val_accuracy: 0.6000
# Epoch 10/100
# 12/12 [==============================] - 216s 18s/step - loss: 0.7662 - accuracy: 0.6403 - val_loss: 0.7690 - val_accuracy: 0.6583
# Epoch 11/100
# 12/12 [==============================] - 208s 17s/step - loss: 0.7156 - accuracy: 0.6729 - val_loss: 0.6855 - val_accuracy: 0.7083
# Epoch 12/100
# 12/12 [==============================] - 188s 16s/step - loss: 0.6752 - accuracy: 0.6931 - val_loss: 1.0913 - val_accuracy: 0.5194
# Epoch 13/100
# 12/12 [==============================] - 187s 16s/step - loss: 0.6133 - accuracy: 0.7333 - val_loss: 1.1438 - val_accuracy: 0.4778
# Epoch 14/100
# 12/12 [==============================] - 188s 16s/step - loss: 0.5804 - accuracy: 0.7431 - val_loss: 0.5472 - val_accuracy: 0.7694
100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0638 - accuracy: 0.9778 - val_loss: 0.6822 - val_accuracy: 0.8528
# Epoch 85/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0846 - accuracy: 0.9667 - val_loss: 0.4246 - val_accuracy: 0.8917
# Epoch 86/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0912 - accuracy: 0.9681 - val_loss: 0.4600 - val_accuracy: 0.8667
# Epoch 87/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0816 - accuracy: 0.9667 - val_loss: 0.5586 - val_accuracy: 0.8722
# Epoch 88/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0592 - accuracy: 0.9778 - val_loss: 0.6226 - val_accuracy: 0.8583
# Epoch 89/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0588 - accuracy: 0.9792 - val_loss: 0.5881 - val_accuracy: 0.8583
# Epoch 90/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0475 - accuracy: 0.9806 - val_loss: 0.5710 - val_accuracy: 0.8639
# Epoch 91/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0660 - accuracy: 0.9764 - val_loss: 0.5720 - val_accuracy: 0.8639
# Epoch 92/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0662 - accuracy: 0.9743 - val_loss: 1.1920 - val_accuracy: 0.7917
# Epoch 93/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0582 - accuracy: 0.9771 - val_loss: 0.8439 - val_accuracy: 0.8417
# Epoch 94/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0575 - accuracy: 0.9806 - val_loss: 0.7135 - val_accuracy: 0.8639
# Epoch 95/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0513 - accuracy: 0.9778 - val_loss: 0.6423 - val_accuracy: 0.8806
# Epoch 96/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0973 - accuracy: 0.9674 - val_loss: 0.3840 - val_accuracy: 0.9111
# Epoch 97/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.1010 - accuracy: 0.9653 - val_loss: 0.3692 - val_accuracy: 0.8889
# Epoch 98/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0913 - accuracy: 0.9722 - val_loss: 0.8406 - val_accuracy: 0.8583
# Epoch 99/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0758 - accuracy: 0.9729 - val_loss: 0.5354 - val_accuracy: 0.9056
# Epoch 100/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0586 - accuracy: 0.9722 - val_loss: 0.7610 - val_accuracy: 0.8972
# CPU times: total: 1d 7h 40min 54s
# Wall time: 5h 29min 6s

# %%
print("10-0.6500
20-0.7611
30-0.8583
40-0.7722
50-0.8611
60-0.6528
70-0.8667
80-0.8750
90-0.8139
100-0.9056"

# %%
training_accuracy = rice_bios_model.history['accuracy'][-1]
validation_accuracy = rice_bios_model.history['val_accuracy'][-1]

print("Training Accuracy:", training_accuracy)
print("Validation Accuracy:", validation_accuracy)
# Out:
# Training Accuracy: 0.9722222089767456
# Validation Accuracy: 0.8972222208976746

# %%
# %%time

rice_bios_model = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100
    )
# Out:
# Epoch 1/100
# 45/45 [==============================] - 187s 4s/step - loss: 0.3199 - accuracy: 0.9139 - val_loss: 1.4226 - val_accuracy: 0.6417
# Epoch 2/100
# 45/45 [==============================] - 197s 4s/step - loss: 0.6759 - accuracy: 0.7917 - val_loss: 2.4736 - val_accuracy: 0.4556
# Epoch 3/100
# 45/45 [==============================] - 199s 4s/step - loss: 0.5825 - accuracy: 0.8181 - val_loss: 26.3542 - val_accuracy: 0.3444
# Epoch 4/100
# 45/45 [==============================] - 207s 5s/step - loss: 0.3456 - accuracy: 0.8701 - val_loss: 2.1229 - val_accuracy: 0.5778
# Epoch 5/100
# 45/45 [==============================] - 209s 5s/step - loss: 0.2714 - accuracy: 0.9222 - val_loss: 1.2124 - val_accuracy: 0.6472
100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0774 - accuracy: 0.9799 - val_loss: 0.4633 - val_accuracy: 0.8889
# Epoch 63/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0899 - accuracy: 0.9674 - val_loss: 0.4459 - val_accuracy: 0.8917
# Epoch 64/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.5046 - val_accuracy: 0.8833
# Epoch 65/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0399 - accuracy: 0.9875 - val_loss: 0.4089 - val_accuracy: 0.8861
# Epoch 66/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0710 - accuracy: 0.9778 - val_loss: 0.7511 - val_accuracy: 0.8667
# Epoch 67/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0317 - accuracy: 0.9903 - val_loss: 0.5201 - val_accuracy: 0.8861
# Epoch 68/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0661 - accuracy: 0.9799 - val_loss: 0.5809 - val_accuracy: 0.8750
# Epoch 69/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0505 - accuracy: 0.9812 - val_loss: 1.1553 - val_accuracy: 0.8306
# Epoch 70/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0697 - accuracy: 0.9812 - val_loss: 0.5845 - val_accuracy: 0.8667
# Epoch 71/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0555 - accuracy: 0.9833 - val_loss: 0.4628 - val_accuracy: 0.8889
# Epoch 72/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0656 - accuracy: 0.9785 - val_loss: 0.3892 - val_accuracy: 0.9222
# Epoch 73/100
# 45/45 [==============================] - 216s 5s/step - loss: 0.0455 - accuracy: 0.9861 - val_loss: 0.5754 - val_accuracy: 0.8694
# Epoch 74/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0621 - accuracy: 0.9778 - val_loss: 0.4443 - val_accuracy: 0.8972
# Epoch 75/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0617 - accuracy: 0.9799 - val_loss: 0.4683 - val_accuracy: 0.8861
# Epoch 76/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0555 - accuracy: 0.9875 - val_loss: 0.3698 - val_accuracy: 0.8972
# Epoch 77/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0362 - accuracy: 0.9861 - val_loss: 0.4728 - val_accuracy: 0.8889
# Epoch 78/100
# 45/45 [==============================] - 215s 5s/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 0.3776 - val_accuracy: 0.9028
# Epoch 79/100
# 45/45 [==============================] - 214s 5s/step - loss: 0.0454 - accuracy: 0.9847 - val_loss: 0.4455 - val_accuracy: 0.8972
# Epoch 80/100
# 45/45 [==============================] - 1698s 38s/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.4615 - val_accuracy: 0.8556
# Epoch 81/100
# 45/45 [==============================] - 186s 4s/step - loss: 0.0449 - accuracy: 0.9847 - val_loss: 0.4438 - val_accuracy: 0.8917
# Epoch 82/100
# 45/45 [==============================] - 186s 4s/step - loss: 0.0448 - accuracy: 0.9840 - val_loss: 0.5291 - val_accuracy: 0.8722
# Epoch 83/100
# 11/45 [======>.......................] - ETA: 2:15 - loss: 0.0453 - accuracy: 0.9858

# %%
model.save('RB_Model.h5')
# Out:
# C:\Users\sasye\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix


# Evaluate model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Classification report
print(classification_report(y_test, y_pred_classes))
# Out:
# 12/12 [==============================] - 6s 496ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       127
#            1       0.89      0.88      0.88       105
#            2       0.91      0.88      0.90       128
#
#     accuracy                           0.91       360
#    macro avg       0.90      0.90      0.90       360
# weighted avg       0.91      0.91      0.91       360

# %%
cm = confusion_matrix(y_test, y_pred_classes)
plt.imshow(cm, cmap=plt.cm.Blues)
plt.colorbar()
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
